# %%
print('Hi')
# Out:
# Hi

# %%
# !pip install pandas numpy
# Out:
# ...
#   Using cached pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
# ...
#   Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 KB 657.6 kB/s eta 0:00:000:00:01m eta 0:00:01
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the '/home/rana/Desktop/AI-ML/venv/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['Name']
titanic[['Name', 'Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
filtered_titanic = titanic[(titanic['Age'] == 30)]
filtered_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 79            80         1       3
# 157          158         0       3
# 178          179         0       2
# 213          214         0       2
# 219          220         0       2
# 244          245         0       3
# 253          254         0       3
# 257          258         1       1
# 286          287         1       3
# 308          309         0       2
# 309          310         1       1
# 322          323         1       2
# 365          366         0       3
# 418          419         0       2
# 452          453         0       1
# 488          489         0       3
# 520          521         1       1
# 534          535         0       3
# 537          538         1       1
# 606          607         0       3
# 726          727         1       2
# 747          748         1       2
# 798          799         0       3
# 799          800         0       3
# 842          843         1       1
#
# ...

# %%
filtered_titanic = filtered_titanic.reset_index(drop=True)
filtered_titanic
# Out:
#     PassengerId  Survived  Pclass  \
# 0            80         1       3
# 1           158         0       3
# 2           179         0       2
# 3           214         0       2
# 4           220         0       2
# 5           245         0       3
# 6           254         0       3
# 7           258         1       1
# 8           287         1       3
# 9           309         0       2
# 10          310         1       1
# 11          323         1       2
# 12          366         0       3
# 13          419         0       2
# 14          453         0       1
# 15          489         0       3
# 16          521         1       1
# 17          535         0       3
# 18          538         1       1
# 19          607         0       3
# 20          727         1       2
# 21          748         1       2
# 22          799         0       3
# 23          800         0       3
# 24          843         1       1
#
# ...
